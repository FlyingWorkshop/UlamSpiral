# %%
import matplotlib.pyplot as plt
import utils

# %%
fig, ax = plt.subplots()
fig.set_size_inches(13, 13)
ax.set_aspect(1)

n = 100000
xv, yv = utils.get_ulam_spiral_coords(n)
ax.scatter(x=xv, y=yv, s=1, c="blue")
# Out:
# 100%|██████████| 100000/100000 [00:00<00:00, 512055.63it/s]
